# %%
import pandas as pd
import math

# %%
df = pd.read_hdf('/home/gublu/Desktop/THINKSTATS/Competition/hdf/maya.h5', 'data')
#tr = df = pd.read_hdf('/home/gublu/Desktop/THINKSTATS/Competition/hdf/application_train.h5', 'data')

# %%
# class
class WOEScores:

  def __init__(self, df):
    self.df = df
    self.ids = self.df['SK_ID_CURR']
    self.df = self.df.drop('SK_ID_CURR', 1)
    self.woe_df = pd.DataFrame()
    self.bin_the_df()
    self.woe_encoded_df()

  def append_woe_scores(self):
    self.split_cols_tablewise_and_calculate_int_score()
    return self.woe_df


  def split_cols_tablewise_and_calculate_int_score(self):
    b_cols = [col for col in list(self.woe_df) if col.startswith('B_')]
    cc_cols = [col for col in list(self.woe_df) if col.startswith('CC_')]
    ip_cols = [col for col in list(self.woe_df) if col.startswith('IP_')]
    pa_cols = [col for col in list(self.woe_df) if col.startswith('PA_')]
    pos_cols = [col for col in list(self.woe_df) if col.startswith('POS_')]
    all_but_tr_te_cols = b_cols + cc_cols + ip_cols + pa_cols + pos_cols
    tr_te_cols = list(set(list(self.woe_df)) - set(all_but_tr_te))
    self.df['WOE_SCORE_B']  = self.woe_df[b_cols].sum(axis=1)
    self.df['WOE_SCORE_CC']  = self.woe_df[cc_cols].sum(axis=1)
    self.df['WOE_SCORE_IP']  = self.woe_df[ip_cols].sum(axis=1)
    self.df['WOE_SCORE_PA']  = self.woe_df[pa_cols].sum(axis=1)
    self.df['WOE_SCORE_POS']  = self.woe_df[pos_cols].sum(axis=1)
    self.df['WOE_SCORE_ALL_BUT_TR_TE']  = self.woe_df[all_but_tr_te_cols].sum(axis=1)
    self.df['WOE_SCORE_TR_TE']  = self.woe_df[tr_te_cols].sum(axis=1)


  def bin_the_df(self):
    categorical_columns = [col for col in list(self.df) if self.df[col].nunique()<=20]
    continuous_columns = [col for col in list(self.df) if self.df[col].nunique()>20]
    for col in continuous_columns:
      z = self.df[col].copy(deep=True)
      try:
        binned = pd.cut(z, 20)
      except ValueError as e:
        continue
      self.woe_df[col] = binned
    self.woe_df = pd.concat([self.woe_df, self.df[categorical_columns]], axis=1)
    self.woe_df['TARGET'] = df['TARGET']


  def woe_encoded_df(self):
    x_total_good = (self.woe_df['TARGET'] == 0).sum()
    x_total_bad = (self.woe_df['TARGET'] == 1).sum()
    for col in list(self.woe_df):
        if col == 'TARGET':
            continue
        bin_woes = []
        bin_labels = self.woe_df[col].unique()
        print(col)
        for bin_label in bin_labels:
            total = (self.woe_df[col] == bin_label).sum()
            good = ((self.woe_df[col] == bin_label) & (self.woe_df['TARGET'] == 0)).sum()
            good_percent = max(good / x_total_good, 1e-100) # to avoid 0 in woe calculation
            bad = ((self.woe_df[col] == bin_label) & (self.woe_df['TARGET'] == 1)).sum()
            bad_percent = max(bad /x_total_bad, 1e-100) # to avoid inf in woe calculation
            woe = round(math.log(good_percent/bad_percent), 5)
            bin_woes.append(woe)
        self.woe_df[col].replace(dict(zip(bin_labels, bin_woes)), inplace= True)

# %%
wdf[['WOE_SCORE_B',	'WOE_SCORE_CC',	'WOE_SCORE_IP',	'WOE_SCORE_PA',	'WOE_SCORE_POS','WOE_SCORE_TR_TE']]
# Out:
#         WOE_SCORE_B  WOE_SCORE_CC  WOE_SCORE_IP  WOE_SCORE_PA  WOE_SCORE_POS  \
# 0          0.551451      0.551451      0.551451      0.551451       0.551451
# 1        224.921666    224.921666    224.921666    224.921666     224.921666
# 2          1.877936      1.877936      1.877936      1.877936       1.877936
# 3         -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 4          2.033646      2.033646      2.033646      2.033646       2.033646
# 5          0.393646      0.393646      0.393646      0.393646       0.393646
# 6          2.520526      2.520526      2.520526      2.520526       2.520526
# 7          3.344781      3.344781      3.344781      3.344781       3.344781
# 8          3.137656      3.137656      3.137656      3.137656       3.137656
# 9         -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 10         2.107306      2.107306      2.107306      2.107306       2.107306
# 11         1.379286      1.379286      1.379286      1.379286       1.379286
# 12         0.877336      0.877336      0.877336      0.877336       0.877336
# 13         3.639256      3.639256      3.639256      3.639256       3.639256
# 14        -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 15         0.132356      0.132356      0.132356      0.132356       0.132356
# 16        -1.348174     -1.348174     -1.348174     -1.348174      -1.348174
# 17        -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 18        -1.090074     -1.090074     -1.090074     -1.090074      -1.090074
# 19         2.669806      2.669806      2.669806      2.669806       2.669806
# 20        -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 21         0.898406      0.898406      0.898406      0.898406       0.898406
# 22         1.137726      1.137726      1.137726      1.137726       1.137726
# 23         1.227886      1.227886      1.227886      1.227886       1.227886
# 24         2.707336      2.707336      2.707336      2.707336       2.707336
# 25         1.503566      1.503566      1.503566      1.503566       1.503566
# 26         0.259356      0.259356      0.259356      0.259356       0.259356
# 27         1.215188      1.215188      1.215188      1.215188       1.215188
# 28        -1.033082     -1.033082     -1.033082     -1.033082      -1.033082
# 29        -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# ...             ...           ...           ...           ...            ...
# 356220    -0.304269     -0.304269     -0.304269     -0.304269      -0.304269
# 356221     2.517031      2.517031      2.517031      2.517031       2.517031
# 356222    -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 356223     3.584608      3.584608      3.584608      3.584608       3.584608
# 356224     0.458868      0.458868      0.458868      0.458868       0.458868
# 356225     2.468811      2.468811      2.468811      2.468811       2.468811
# 356226     1.556601      1.556601      1.556601      1.556601       1.556601
# 356227    -1.086409     -1.086409     -1.086409     -1.086409      -1.086409
# 356228     1.733251      1.733251      1.733251      1.733251       1.733251
# 356229    -0.869802     -0.869802     -0.869802     -0.869802      -0.869802
# 356230     1.528701      1.528701      1.528701      1.528701       1.528701
# 356231     2.893208      2.893208      2.893208      2.893208       2.893208
# 356232     3.032021      3.032021      3.032021      3.032021       3.032021
# 356233     2.647238      2.647238      2.647238      2.647238       2.647238
# 356234     2.062248      2.062248      2.062248      2.062248       2.062248
# 356235    -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 356236     0.224651      0.224651      0.224651      0.224651       0.224651
# 356237     2.285948      2.285948      2.285948      2.285948       2.285948
# 356238     3.755691      3.755691      3.755691      3.755691       3.755691
# 356239     2.618538      2.618538      2.618538      2.618538       2.618538
# 356240     1.491481      1.491481      1.491481      1.491481       1.491481
# 356241    -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 356242     3.358781      3.358781      3.358781      3.358781       3.358781
# 356243     2.563111      2.563111      2.563111      2.563111       2.563111
# 356244    -0.518532     -0.518532     -0.518532     -0.518532      -0.518532
# 356245     0.648461      0.648461      0.648461      0.648461       0.648461
# 356246    -0.245094     -0.245094     -0.245094     -0.245094      -0.245094
# 356247    -0.228719     -0.228719     -0.228719     -0.228719      -0.228719
# 356248     3.295588      3.295588      3.295588      3.295588       3.295588
# 356249     1.087341      1.087341      1.087341      1.087341       1.087341
#
#         WOE_SCORE_TR_TE
# 0              0.551451
# 1            224.921666
# 2              1.877936
# 3             -0.245094
# 4              2.033646
# 5              0.393646
# 6              2.520526
# 7              3.344781
# 8              3.137656
# 9             -0.245094
# 10             2.107306
# 11             1.379286
# 12             0.877336
# 13             3.639256
# 14            -0.245094
# 15             0.132356
# 16            -1.348174
# 17            -0.245094
# 18            -1.090074
# 19             2.669806
# 20            -0.245094
# 21             0.898406
# 22             1.137726
# 23             1.227886
# 24             2.707336
# 25             1.503566
# 26             0.259356
# 27             1.215188
# 28            -1.033082
# 29            -0.245094
# ...                 ...
# 356220        -0.304269
# 356221         2.517031
# 356222        -0.245094
# 356223         3.584608
# 356224         0.458868
# 356225         2.468811
# 356226         1.556601
# 356227        -1.086409
# 356228         1.733251
# 356229        -0.869802
# 356230         1.528701
# 356231         2.893208
# 356232         3.032021
# 356233         2.647238
# 356234         2.062248
# 356235        -0.245094
# 356236         0.224651
# 356237         2.285948
# 356238         3.755691
# 356239         2.618538
# 356240         1.491481
# 356241        -0.245094
# 356242         3.358781
# 356243         2.563111
# 356244        -0.518532
# 356245         0.648461
# 356246        -0.245094
# 356247        -0.228719
# 356248         3.295588
# 356249         1.087341
#
# [356250 rows x 6 columns]

# %%
wdf = WOEScores(df).append_woe_scores()
# Out:
# /home/gublu/Documents/Python/venv/lib/python3.6/site-packages/numpy/core/function_base.py:133: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /home/gublu/Documents/Python/venv/lib/python3.6/site-packages/numpy/core/function_base.py:142: RuntimeWarning: invalid value encountered in add
#   y += start
# /home/gublu/Documents/Python/venv/lib/python3.6/site-packages/numpy/core/function_base.py:133: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /home/gublu/Documents/Python/venv/lib/python3.6/site-packages/numpy/core/function_base.py:133: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /home/gublu/Documents/Python/venv/lib/python3.6/site-packages/numpy/core/function_base.py:142: RuntimeWarning: invalid value encountered in add
#   y += start
# /home/gublu/Documents/Python/venv/lib/python3.6/site-packages/numpy/core/function_base.py:133: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# AMT_CREDIT/AMT_ANNUITY
# DAYS_BIRTH
# EXT_SOURCE_3
# EXT_SOURCE_2
# EXT_SOURCE_1
# AMT_CREDIT
# AMT_ANNUITY
# AMT_CREDIT/AMT_GOODS_PRICE
# DAYS_ID_PUBLISH
# DAYS_EMPLOYED/DAYS_BIRTH
# OWN_CAR_AGE/DAYS_BIRTH
# DAYS_REGISTRATION
# AMT_ANNUITY/AMT_INCOME_TOTAL
# REGION_POPULATION_RELATIVE
# AMT_GOODS_PRICE
# AMT_CREDIT/AMT_INCOME_TOTAL
# TOTALAREA_MODE
# AMT_INCOME_TOTAL/CNT_CHILDREN
# AMT_INCOME_TOTAL/CNT_FAM_MEMBERS
# AMT_INCOME_TOTAL
# BASEMENTAREA_AVG
# LIVINGAREA_MODE
# YEARS_BEGINEXPLUATATION_AVG
# LANDAREA_MODE
# NONLIVINGAREA_AVG
# INCOME/CNT_FAM_MEMBERS*AMT_CREDIT
# NEW_SOURCES_PROD
# DAYS_LAST_PHONE_CHANGE
# OWN_CAR_AGE
# AMT_INCOME_TOTAL/DAYS_BIRTH
# AMT_CREDIT/DAYS_BIRTH
# EXT_SCORES_STD
# external_sources_weighted
# EXT_SOURCES_min
# EXT_SOURCES_max
# EXT_SOURCES_sum
# EXT_SOURCES_mean
# EXT_SOURCES_nanmedian
# PA_AMT_APPLICATION/AMT_CREDIT_MEAN
# PA_AMT_APPLICATION/AMT_CREDIT_MAX
# PA_CNT_PAYMENT_SUM
# PA_CNT_PAYMENT_MEAN
# PA_CNT_PAYMENT_VAR
# PA_CNT_PAYMENT_MAX
# PA_AMT_CREDIT/AMT_DOWN_PAYMENT_MEAN
# PA_AMT_CREDIT/AMT_DOWN_PAYMENT_MAX
# PA_AMT_APPLICATION_MAX
# PA_AMT_APPLICATION_MEAN
# PA_AMT_ANNUITY_MEAN
# PA_AMT_ANNUITY_MAX
# PA_AMT_ANNUITY_MIN
# PA_AMT_CREDIT_MAX
# PA_AMT_CREDIT_MEAN
# PA_DAYS_DECISION_MIN
# PA_DAYS_DECISION_MEAN
# PA_DAYS_DECISION_MAX
# PA_DAYS_DECISION_VAR
# PA_AMT_DOWN_PAYMENT_MEAN
# PA_AMT_DOWN_PAYMENT_MAX
# PA_RATE_DOWN_PAYMENT_MEAN
# PA_RATE_DOWN_PAYMENT_MAX
# PA_RATE_DOWN_PAYMENT_SUM
# PA_CASH_DAYS_TERMINATION_MIN
# PA_CASH_AMT_ANNUITY_MAX
# PA_CASH_DAYS_LAST_DUE_1ST_VERSION_MAX
# PA_CONSUMER_DAYS_TERMINATION_MIN
# PA_CONSUMER_AMT_ANNUITY_MEAN
# PA_CONSUMER_AMT_ANNUITY_MAX
# PA_CONSUMER_AMT_DOWN_PAYMENT_MEAN
# PA_CONSUMER_AMT_DOWN_PAYMENT/AMT_CREDIT_MEAN
# PA_CONSUMER_DAYS_LAST_DUE_1ST_VERSION_MAX
# PA_CONSUMER_AMT_GOODS_PRICE_MEAN
# PA_NAME_CLIENT_TYPE_REPEATER
# PA_REFUSED_DAYS_DECISION_MAX
# PA_REFUSED_CNT_PAYMENT_MEAN
# PA_REFUSED_CNT_PAYMENT_SUM
# PA_REFUSED_AMT_ANNUITY_MEAN
# PA_REFUSED_AMT_ANNUITY_MAX
# PA_REFUSED_AMT_GOODS_PRICE_MEAN
# PA_REFUSED_AMT_CREDIT_MAX
# IP_DAYS_ENTRY_PAYMENT_MIN
# IP_DAYS_ENTRY_PAYMENT_MAX
# IP_DAYS_ENTRY_PAYMENT_MEAN
# IP_AMT_INSTALMENT_MIN
# IP_AMT_INSTALMENT_SUM
# IP_AMT_INSTALMENT_MEAN
# IP_AMT_INSTALMENT_MAX
# IP_AMT_INSTALMENT_STD
# IP_DBD_SUM
# IP_DBD_STD
# IP_DBD_MEAN
# IP_DBD_MAX
# IP_DBD_MIN
# IP_AMT_PAYMENT_SUM
# IP_AMT_PAYMENT_MIN
# IP_AMT_PAYMENT_MEAN
# IP_AMT_PAYMENT_STD
# IP_AMT_PAYMENT_MAX
# IP_DPD_MEAN
# IP_DPD_STD
# IP_DPD_SUM
# IP_AMT_PAYMENT/AMT_INSTALMENT_MEAN
# IP_AMT_INSTALMENT-AMT_PAYMENT_MEAN
# IP_AMT_INSTALMENT-AMT_PAYMENT_MAX
# IP_AMT_INSTALMENT-AMT_PAYMENT_VAR
# IP_DELAY_IN_PAYMENT_MEAN
# IP_DAYS_INSTALMENT_MIN
# POS_MONTHS_BALANCE_MEAN
# POS_MONTHS_BALANCE_SIZE
# POS_MONTHS_BALANCE_MAX
# POS_MONTHS_BALANCE_MIN
# POS_MONTHS_BALANCE_VAR
# POS_SK_DPD_MEAN
# POS_DPD_MINUS_DPD_DEF_MAX
# POS_LATEST_SK_DPD_DEF
# CC_LATEST_AMT_TOTAL_RECEIVABLE
# CC_CNT_DRAWINGS_ATM_CURRENT_MEAN
# CC_CNT_DRAWINGS_ATM_CURRENT_VAR
# CC_CNT_DRAWINGS_ATM_CURRENT_MAX
# CC_CNT_DRAWINGS_ATM_CURRENT_SUM
# CC_AMT_PAYMENT_CURRENT_MEAN
# CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN
# CC_CNT_DRAWINGS_CURRENT_VAR
# CC_CNT_DRAWINGS_CURRENT_MEAN
# CC_CNT_DRAWINGS_CURRENT_SUM
# CC_AMT_BALANCE_MEAN
# CC_AMT_BALANCE_MAX
# CC_AMT_BALANCE_MIN
# CC_MONTHS_BALANCE_MEAN
# CC_MONTHS_BALANCE_MIN
# CC_MONTHS_BALANCE_VAR
# CC_MONTHS_BALANCE_SUM
# CC_AMT_DRAWINGS_CURRENT_MEAN
# CC_AMT_DRAWINGS_CURRENT_MAX
# CC_COUNT
# B_AMT_CREDIT_SUM_MEAN
# B_AMT_CREDIT_SUM_SUM
# B_AMT_CREDIT_MAX_OVERDUE_MEAN
# B_SK_ID_BUREAU_COUNT
# B_DAYS_CREDIT_ENDDATE_MEAN
# B_DAYS_CREDIT_MEAN
# B_DAYS_CREDIT_MIN
# B_DAYS_CREDIT_VAR
# B_DAYS_CREDIT_MAX
# B_AMT_CREDIT_SUM_DEBT_MEAN
# B_AMT_CREDIT_SUM_DEBT_SUM
# B_AMT_CREDIT_SUM_LIMIT_MEAN
# B_BB_LATEST_MONTHS_BALANCE_MAX
# B_DAYS_CREDIT_UPDATE_MEAN
# B_AMT_CREDIT_SUM_OVERDUE_SUM
# B_AMT_CREDIT_SUM_OVERDUE_MEAN
# B_CREDIT_ACTIVE_DAYS_CREDIT_MEAN
# B_CREDIT_ACTIVE_DAYS_CREDIT_VAR
# B_CREDIT_ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
# B_CREDIT_ACTIVE_DAYS_CREDIT_UPDATE_MEAN
# B_CREDIT_ACTIVE_AMT_CREDIT_SUM_MEAN
# B_CREDIT_ACTIVE_AMT_CREDIT_SUM_SUM
# B_CREDIT_ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
# B_CREDIT_ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
# B_CREDIT_ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN
# B_CREDIT_ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN
# B_CREDIT_ACTIVE_AMT_ANNUITY_SUM
# B_CREDIT_ACTIVE_CLOSEDDAYS_CREDIT_VAR
# B_CREDIT_ACTIVE_CLOSEDDAYS_CREDIT_MEAN
# B_CREDIT_ACTIVE_CLOSEDAMT_CREDIT_SUM_MEAN
# B_CREDIT_ACTIVE_CLOSEDAMT_CREDIT_SUM_SUM
# B_CREDIT_ACTIVE_CLOSEDDAYS_CREDIT_ENDDATE_MEAN
# B_CREDIT_ACTIVE_CLOSEDDAYS_CREDIT_UPDATE_MEAN
# B_CREDIT_ACTIVE_CLOSEDAMT_CREDIT_MAX_OVERDUE_MEAN
# TR_AMT_ANNUITY/PA_CASH_AMT_ANNUITY_MAX
# TR_AMT_ANNUITY/PA_CONSUMER_AMT_ANNUITY_MAX
# TR_AMT_CREDIT/PA_CASH_AMT_ANNUITY_MAX
# TR_AMT_CREDIT/PA_CONSUMER_AMT_ANNUITY_MAX
# TR_AMT_ANNUITY/IP_AMT_PAYMENT_MAX
# TR_AMT_ANNUITY/IP_AMT_PAYMENT_MEAN
# TR_NEW_TOTAL_ACTIVE_ANNUITY_PAYMENTS
# AMT_REQ_CREDIT_BUREAU_YEAR
# OBS_60_CNT_SOCIAL_CIRCLE
# PA_SK_ID_PREV_NUNIQUE
# PA_NAME_YIELD_GROUP_HIGH
# PA_NAME_PRODUCT_TYPE_X-SELL
# PA_NAME_PRODUCT_TYPE_WALK-IN
# IP_SK_ID_PREV_NUNIQUE
# int_score_x
# int_score_y
# all_woe_score
# NEW_IS_DAYS_EMPLOYED_365243
# NEW_LIVE_IND_KURT
# have_previous_application_record
# NEW_LIVE_IND_SUM_NN
# NEW_LIVE_IND_SUM_NY
# NEW_LIVE_IND_SUM_YN
# NEW_LIVE_IND_SUM_YY
# NEW_IS_RETIRED_0
# NEW_IS_RETIRED_1
# CODE_GENDER_F
# CODE_GENDER_M
# NEW_IS_EMPLOYED_FOR_LONG_0
# NEW_IS_EMPLOYED_FOR_LONG_1
# DAYS_EMPLOYED
# NEW_DOC_IND_KURT
# NEW_NUMBER_OF_DOCUMENTS_SUBMITTED
# NEW_CONTACT_IND_SUM
# NEW_CONTACT_IND_KURT
# CNT_CHILDREN/CNT_FAM_MEMBERS
# NEW_REG_IND_SUM
# NEW_REG_IND_KURT
# CC_LATEST_SK_DPD_DEF
# B_BB_LATEST_STATUS_FIRST
# B_CREDIT_DAY_OVERDUE_NUNIQUE
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a114b34ed875> in <module>()
# ----> 1 wdf = WOEScores(df).append_woe_scores()
#
# <ipython-input-19-ac04cc759bb4> in append_woe_scores(self)
#      11
#      12   def append_woe_scores(self):
# ---> 13     self.split_cols_tablewise_and_calculate_int_score()
#      14     return self.df
#      15
#
# <ipython-input-19-ac04cc759bb4> in split_cols_tablewise_and_calculate_int_score(self)
#      22     pos_cols = [col for col in list(self.woe_df) if col.startswith('POS_')]
#      23     all_but_tr_te_cols = b_cols + cc_cols + ip_cols + pa_cols + pos_cols
# ---> 24     tr_te_cols = list(set(list(self.woe_df)) - set(all_but_tr_te))
#      25     self.df['WOE_SCORE_B']  = self.woe_df[b_cols].sum(axis=1)
#      26     self.df['WOE_SCORE_CC']  = self.woe_df[cc_cols].sum(axis=1)
#
# NameError: name 'all_but_tr_te' is not defined
